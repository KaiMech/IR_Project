# %% [markdown]
# # Inverted Index

# %%
# data\tot25\subsets\train80\train100k-corpus.jsonl.gz
# train corpus directory
# evaluation code in Models/posting_list_operations.ipynb

# %%
import pandas as pd
from collections import defaultdict, Counter
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import json
import gzip
import pickle 
import numpy as np
from array import array
from datetime import datetime
import shelve
import math

# %% [markdown]
# ## Preprocessing

# %%
#for stopword removal
nltk.download('stopwords')
stop = set(stopwords.words('english') + list(string.punctuation))


# Function to tokenize and preprocess a document
def preprocess(text):
    tokens = set(word_tokenize(text.lower())) # get all tokens
    return [i for i in tokens if i not in stop] # get all tokens without stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Inverted  Index Creation

# %%
try:
    import orjson as _json
    loads = _json.loads
except Exception:
    import json as _json
    loads = _json.loads
    
OUT_PATH = "./data/inverted_index.db"
corpus = "../data/tot25/subsets/train80/train100k-corpus.jsonl.gz"

UNSIGNED_INTEGER_MAX = 2**32 - 1 # max 32 bit unsigned integer size

counter = 0
inverted_index = defaultdict(lambda:array('I'))
#r --> read, t --> text not bytes
with gzip.open(corpus, "rt", encoding = "utf8") as f_in:
    for line_number, line in enumerate(f_in, start = 1):
        counter += 1
        line = line.strip()
        data = loads(line)
        id = int(data.get("id"))
        #safety check to see whether everything can be stored as 32 bit unsigned integer (else need Q parameter for defaultdict parameter)
        if not UNSIGNED_INTEGER_MAX > id > 0:
            raise OverflowError("Invalid ID for 32 bit unsigned integer, need 64 bit") 
        tokens = set(preprocess(data.get("text")))
        for token in tokens:
            inverted_index[token].append(int(data.get("id", "")))
        if counter % 5_000 == 0:
            print(f"read {counter} lines")
# 30 mins
# Out:
# read 5000 lines
# read 10000 lines
# read 15000 lines
# read 20000 lines
# read 25000 lines
# read 30000 lines
# read 35000 lines
# read 40000 lines
# read 45000 lines
# read 50000 lines
# read 55000 lines
# read 60000 lines
# read 65000 lines
# read 70000 lines
# read 75000 lines
# read 80000 lines
# read 85000 lines
# read 90000 lines
# read 95000 lines
# read 100000 lines

# %%
print(len(inverted_index))
counter = 0
with shelve.open(OUT_PATH) as db:
    for term, posting_list in inverted_index.items():
        db[term] = posting_list
        counter += 1
        if counter % 5_000 == 0:
            print(f"processed {counter} words")
    db.sync()

#28 mins
# Out:
# 1572117
# processed 5000 words
# processed 10000 words
# processed 15000 words
# processed 20000 words
# processed 25000 words
# processed 30000 words
# processed 35000 words
# processed 40000 words
# processed 45000 words
# processed 50000 words
# processed 55000 words
# processed 60000 words
# processed 65000 words
# processed 70000 words
# processed 75000 words
# processed 80000 words
# processed 85000 words
# processed 90000 words
# processed 95000 words
# processed 100000 words
# processed 105000 words
# processed 110000 words
# processed 115000 words
# processed 120000 words
# processed 125000 words
# processed 130000 words
# processed 135000 words
# processed 140000 words
# processed 145000 words
# processed 150000 words
# processed 155000 words
# processed 160000 words
# processed 165000 words
# processed 170000 words
# processed 175000 words
# processed 180000 words
# processed 185000 words
# processed 190000 words
# processed 195000 words
# processed 200000 words
# processed 205000 words
# processed 210000 words
# processed 215000 words
# processed 220000 words
# processed 225000 words
# processed 230000 words
# processed 235000 words
# processed 240000 words
# processed 245000 words
# processed 250000 words
# processed 255000 words
# processed 260000 words
# processed 265000 words
# processed 270000 words
# processed 275000 words
# processed 280000 words
# processed 285000 words
# processed 290000 words
# processed 295000 words
# processed 300000 words
# processed 305000 words
# processed 310000 words
# processed 315000 words
# processed 320000 words
# processed 325000 words
# processed 330000 words
# processed 335000 words
# processed 340000 words
# processed 345000 words
# processed 350000 words
# processed 355000 words
# processed 360000 words
# processed 365000 words
# processed 370000 words
# processed 375000 words
# processed 380000 words
# processed 385000 words
# processed 390000 words
# processed 395000 words
# processed 400000 words
# processed 405000 words
# processed 410000 words
# processed 415000 words
# processed 420000 words
# processed 425000 words
# processed 430000 words
# processed 435000 words
# processed 440000 words
# processed 445000 words
# processed 450000 words
# processed 455000 words
# processed 460000 words
# processed 465000 words
# processed 470000 words
# processed 475000 words
# processed 480000 words
# processed 485000 words
# processed 490000 words
# processed 495000 words
# processed 500000 words
# processed 505000 words
# processed 510000 words
# processed 515000 words
# processed 520000 words
# processed 525000 words
# processed 530000 words
# processed 535000 words
# processed 540000 words
# processed 545000 words
# processed 550000 words
# processed 555000 words
# processed 560000 words
# processed 565000 words
# processed 570000 words
# processed 575000 words
# processed 580000 words
# processed 585000 words
# processed 590000 words
# processed 595000 words
# processed 600000 words
# processed 605000 words
# processed 610000 words
# processed 615000 words
# processed 620000 words
# processed 625000 words
# processed 630000 words
# processed 635000 words
# processed 640000 words
# processed 645000 words
# processed 650000 words
# processed 655000 words
# processed 660000 words
# processed 665000 words
# processed 670000 words
# processed 675000 words
# processed 680000 words
# processed 685000 words
# processed 690000 words
# processed 695000 words
# processed 700000 words
# processed 705000 words
# processed 710000 words
# processed 715000 words
# processed 720000 words
# processed 725000 words
# processed 730000 words
# processed 735000 words
# processed 740000 words
# processed 745000 words
# processed 750000 words
# processed 755000 words
# processed 760000 words
# processed 765000 words
# processed 770000 words
# processed 775000 words
# processed 780000 words
# processed 785000 words
# processed 790000 words
# processed 795000 words
# processed 800000 words
# processed 805000 words
# processed 810000 words
# processed 815000 words
# processed 820000 words
# processed 825000 words
# processed 830000 words
# processed 835000 words
# processed 840000 words
# processed 845000 words
# processed 850000 words
# processed 855000 words
# processed 860000 words
# processed 865000 words
# processed 870000 words
# processed 875000 words
# processed 880000 words
# processed 885000 words
# processed 890000 words
# processed 895000 words
# processed 900000 words
# processed 905000 words
# processed 910000 words
# processed 915000 words
# processed 920000 words
# processed 925000 words
# processed 930000 words
# processed 935000 words
# processed 940000 words
# processed 945000 words
# processed 950000 words
# processed 955000 words
# processed 960000 words
# processed 965000 words
# processed 970000 words
# processed 975000 words
# processed 980000 words
# processed 985000 words
# processed 990000 words
# processed 995000 words
# processed 1000000 words
# processed 1005000 words
# processed 1010000 words
# processed 1015000 words
# processed 1020000 words
# processed 1025000 words
# processed 1030000 words
# processed 1035000 words
# processed 1040000 words
# processed 1045000 words
# processed 1050000 words
# processed 1055000 words
# processed 1060000 words
# processed 1065000 words
# processed 1070000 words
# processed 1075000 words
# processed 1080000 words
# processed 1085000 words
# processed 1090000 words
# processed 1095000 words
# processed 1100000 words
# processed 1105000 words
# processed 1110000 words
# processed 1115000 words
# processed 1120000 words
# processed 1125000 words
# processed 1130000 words
# processed 1135000 words
# processed 1140000 words
# processed 1145000 words
# processed 1150000 words
# processed 1155000 words
# processed 1160000 words
# processed 1165000 words
# processed 1170000 words
# processed 1175000 words
# processed 1180000 words
# processed 1185000 words
# processed 1190000 words
# processed 1195000 words
# processed 1200000 words
# processed 1205000 words
# processed 1210000 words
# processed 1215000 words
# processed 1220000 words
# processed 1225000 words
# processed 1230000 words
# processed 1235000 words
# processed 1240000 words
# processed 1245000 words
# processed 1250000 words
# processed 1255000 words
# processed 1260000 words
# processed 1265000 words
# processed 1270000 words
# processed 1275000 words
# processed 1280000 words
# processed 1285000 words
# processed 1290000 words
# processed 1295000 words
# processed 1300000 words
# processed 1305000 words
# processed 1310000 words
# processed 1315000 words
# processed 1320000 words
# processed 1325000 words
# processed 1330000 words
# processed 1335000 words
# processed 1340000 words
# processed 1345000 words
# processed 1350000 words
# processed 1355000 words
# processed 1360000 words
# processed 1365000 words
# processed 1370000 words
# processed 1375000 words
# processed 1380000 words
# processed 1385000 words
# processed 1390000 words
# processed 1395000 words
# processed 1400000 words
# processed 1405000 words
# processed 1410000 words
# processed 1415000 words
# processed 1420000 words
# processed 1425000 words
# processed 1430000 words
# processed 1435000 words
# processed 1440000 words
# processed 1445000 words
# processed 1450000 words
# processed 1455000 words
# processed 1460000 words
# processed 1465000 words
# processed 1470000 words
# processed 1475000 words
# processed 1480000 words
# processed 1485000 words
# processed 1490000 words
# processed 1495000 words
# processed 1500000 words
# processed 1505000 words
# processed 1510000 words
# processed 1515000 words
# processed 1520000 words
# processed 1525000 words
# processed 1530000 words
# processed 1535000 words
# processed 1540000 words
# processed 1545000 words
# processed 1550000 words
# processed 1555000 words
# processed 1560000 words
# processed 1565000 words
# processed 1570000 words

# %% [markdown]
# Quick sanity check

# %%
INVERTED_INDEX_PATH = "./data/inverted_index.db"

with shelve.open(INVERTED_INDEX_PATH, flag = "r") as db:
    print(f"number of terms: {len(db)}")
    print(f"documents containing mannheim: {db["mannheim"]}")
# Out:
# number of terms: 1572117
# documents containing mannheim: array('I', [700, 4407019, 4577884, 5814879, 6253823, 6272189, 6343860, 7037805, 8132208, 8250877, 8351187, 8710621, 11210342, 11210433, 11210473, 11210507, 11210643, 11210745, 11451764, 11981133, 12037783, 12325101, 12556186, 12989055, 14956021, 15584759, 16006531, 17997957, 19218099, 20071648, 20435694, 20865031, 22145651, 23248722, 23643764, 23672923, 24355525, 24449669, 25272420, 26281786, 27995863, 50564, 56166, 58865, 62654, 63742, 68322, 73419, 78747, 81586, 86351, 88817, 95184, 102198, 129332, 144135, 147687, 31996140, 33244287, 33792780, 35313233, 36029833, 37909853, 37918094, 39246316, 43128406, 44348411, 44542304, 50109950, 50294920, 57311508, 59439318, 60797380, 65562716, 66250007, 67041387, 67278971, 68500305, 70375857, 72304317, 72535805, 164640, 177032, 184843, 184846, 184847, 187709, 248551, 276356, 369155, 379216, 492132, 537560, 980439, 1191147, 1319121, 1522205, 1544929, 1866112, 1971360, 2150754, 2197440, 2281745, 2290662, 2547575, 2629664, 2783571])

# %%
with gzip.open(corpus) as f:
    for line in f:
        line = line.strip()
        data = loads(line)
        id = int(data.get("id"))
        if id == 700: 
            if "Mannheim" in data.get("text"):
                print("passed test")
            print(data)
            break
        if id > 10000:
            print("failed test")
            break
# Out:
# passed test
# {'id': '700', 'url': 'https://en.wikipedia.org/wiki/Arthur%20Schopenhauer', 'title': 'Arthur Schopenhauer', 'text': 'Arthur Schopenhauer ( , ; 22 February 1788\xa0– 21 September 1860) was a German philosopher. He is best known for his 1818 work The World as Will and Representation (expanded in 1844), which characterizes the phenomenal world as the manifestation of a blind and irrational noumenal will. Building on the transcendental idealism of Immanuel Kant (1724–1804), Schopenhauer developed an atheistic metaphysical and ethical system that rejected the contemporaneous ideas of German idealism. He was among the first thinkers in Western philosophy to share and affirm significant tenets of Indian philosophy, such as asceticism, denial of the self, and the notion of the world-as-appearance. His work has been described as an exemplary manifestation of philosophical pessimism. Though his work failed to garner substantial attention during his lifetime, Schopenhauer had a posthumous impact across various disciplines, including philosophy, literature, and science. His writing on aesthetics, morality, and psychology have influenced many thinkers and artists.\n\nLife\n\nEarly life \n\nArthur Schopenhauer was born on 22 February 1788, in Danzig (then part of the Polish–Lithuanian Commonwealth; present-day Gdańsk, Poland) on Heiligegeistgasse (present day Św. Ducha 47), the son of Johanna Schopenhauer (née Trosiener; 1766–1838) and Heinrich Floris Schopenhauer (1747–1805), both descendants of wealthy German patrician families. While they came from a Protestant background, neither of them was very religious; both supported the French Revolution, were republicans, cosmopolitans and Anglophiles. When Danzig became part of Prussia in 1793, Heinrich moved to Hamburg—a free city with a republican constitution. His firm continued trading in Danzig where most of their extended families remained. Adele, Arthur\'s only sibling, was born on 12 July 1797.\n\nIn 1797, Arthur was sent to Le Havre to live with the family of his father\'s business associate, Grégoire de Blésimaire. He seemed to enjoy his two-year stay there, learning to speak French and fostering a life-long friendship with Jean Anthime Grégoire de Blésimaire. As early as 1799, Arthur started playing the flute.\n\nIn 1803, he accompanied his parents on a European tour of Holland, Britain, France, Switzerland, Austria and Prussia. Viewed as primarily a pleasure tour, Heinrich used the opportunity to visit some of his business associates abroad.\n\nHeinrich offered Arthur a choice: he could stay at home and start preparations for university, or he could travel with them and continue his merchant education. Arthur chose to travel with them. He deeply regretted his choice later because the merchant training was very tedious. He spent twelve weeks of the tour attending school in Wimbledon, where he was disillusioned by strict and intellectually shallow Anglican religiosity. He continued to sharply criticize Anglican religiosity later in life despite his general Anglophilia. He was also under pressure from his father, who became very critical of his educational results.\n\nIn 1805, Heinrich drowned in a canal near their home in Hamburg. Although it was possible that his death was accidental, his wife and son believed that it was suicide. He was prone to anxiety and depression, each becoming more pronounced later in his life. Heinrich had become so fussy, even his wife started to doubt his mental health. "There was, in the father\'s life, some dark and vague source of fear which later made him hurl himself to his death from the attic of his house in Hamburg."\n\nArthur showed similar moodiness during his youth and often acknowledged that he inherited it from his father. There were other instances of serious mental health problems on his father\'s side of the family. Despite his hardship, Schopenhauer liked his father and later referred to him in a positive light. Heinrich Schopenhauer left th ...

# %% [markdown]
# ## TF-IDF

# %%
#for stopword removal
nltk.download('stopwords')
stop = set(stopwords.words('english') + list(string.punctuation))


# Function to tokenize and preprocess a document
def preprocess_list(text):
    tokens = list(word_tokenize(text.lower())) # get all tokens
    return [i for i in tokens if i not in stop] # get all tokens without stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# creating term frequencies

# %%
try:
    import orjson as _json
    loads = _json.loads
except Exception:
    import json as _json
    loads = _json.loads

OUT_PATH_TF_IDF = "./data/tf_idf.db"
corpus = "../data/tot25/subsets/train80/train100k-corpus.jsonl.gz"

term_postings = defaultdict(Counter) # here we map each term to a counter map doc_id \mapsto tf

counter = 0
with gzip.open(corpus, "rt", encoding = "utf8") as f_in:
    for line_number, line in enumerate(f_in, start = 1):
        counter += 1
        data = loads(line.strip())
        id = int(data.get("id"))
        # the upper preprocess function returns each token only once, hence we adapt to another one
        tokens = preprocess_list(data.get("text"))
        tf_counts = Counter(tokens)
        for term, tf in tf_counts.items():
            term_postings[term][id] = tf
        
        if counter % 5_000 == 0:
            print(f"processed {counter} lines")
    
# 23 min
# Out:
# processed 5000 lines
# processed 10000 lines
# processed 15000 lines
# processed 20000 lines
# processed 25000 lines
# processed 30000 lines
# processed 35000 lines
# processed 40000 lines
# processed 45000 lines
# processed 50000 lines
# processed 55000 lines
# processed 60000 lines
# processed 65000 lines
# processed 70000 lines
# processed 75000 lines
# processed 80000 lines
# processed 85000 lines
# processed 90000 lines
# processed 95000 lines
# processed 100000 lines

# %% [markdown]
# from term frequencies creating idf and storing everything in db

# %%
TOTAL_DOCUMENTS = 100_000 # from 
with shelve.open(OUT_PATH_TF_IDF) as db:
    for term, posting in term_postings.items():
        # note here counter is the map for document to frequency, not a counter in terms of how many iterations have been executed!
        df = len(posting)
        idf = math.log(TOTAL_DOCUMENTS / df)
        #  since we sort beforehand the document id and tfs are now sorted the same way as well and belong together with the same index :)
        items = sorted(posting.items())
        doc_ids = array("I", (doc for doc, _ in items))
        # note: for the doc_ids we use I (32 bit integer), as they account for the max range of the document ids and H (16 bit) with a maximum of 65536 (2^16 - 1) is not big enough
        # for the term frequencies, since no wikipedia abstract contains nearly as many tokens as that, we use H
        # uppercase means unsigned, lower case means signed!
        tfs = array('H', (tf for _, tf in items))
        db[term] = {"df": df, "idf": idf, "doc_ids": doc_ids, "tfs": tfs}
    db.sync()
    
# 20 mins

# %% [markdown]
# Quick sanity check

# %%
TF_IDF_PATH = "./data/tf_idf.db"

with shelve.open(TF_IDF_PATH, flag = "r") as db:
    print(f"number of terms: {len(db)}")
    results_mannheim = db["mannheim"]
    print(results_mannheim)
    if 700 in results_mannheim.get("doc_ids"):
        print("passed")
    else:
        print("failed test")
# Out:
# number of terms: 1572117
# {'df': 107, 'idf': 6.840096630508322, 'doc_ids': array('I', [700, 50564, 56166, 58865, 62654, 63742, 68322, 73419, 78747, 81586, 86351, 88817, 95184, 102198, 129332, 144135, 147687, 164640, 177032, 184843, 184846, 184847, 187709, 248551, 276356, 369155, 379216, 492132, 537560, 980439, 1191147, 1319121, 1522205, 1544929, 1866112, 1971360, 2150754, 2197440, 2281745, 2290662, 2547575, 2629664, 2783571, 4407019, 4577884, 5814879, 6253823, 6272189, 6343860, 7037805, 8132208, 8250877, 8351187, 8710621, 11210342, 11210433, 11210473, 11210507, 11210643, 11210745, 11451764, 11981133, 12037783, 12325101, 12556186, 12989055, 14956021, 15584759, 16006531, 17997957, 19218099, 20071648, 20435694, 20865031, 22145651, 23248722, 23643764, 23672923, 24355525, 24449669, 25272420, 26281786, 27995863, 31996140, 33244287, 33792780, 35313233, 36029833, 37909853, 37918094, 39246316, 43128406, 44348411, 44542304, 50109950, 50294920, 57311508, 59439318, 60797380, 65562716, 66250007, 67041387, 67278971, 68500305, 70375857, 72304317, 72535805]), 'tfs': array('H', [1, 1, 1, 5, 1, 2, 1, 1, 1, 1, 2, 12, 3, 2, 2, 2, 1, 3, 1, 1, 1, 1, 4, 1, 1, 1, 5, 1, 1, 1, 1, 1, 1, 1, 1, 3, 1, 2, 1, 1, 1, 2, 1, 1, 2, 1, 1, 1, 2, 4, 3, 1, 6, 1, 6, 2, 1, 2, 10, 2, 1, 3, 1, 1, 1, 2, 1, 3, 2, 3, 1, 1, 1, 2, 3, 1, 1, 1, 1, 1, 1, 4, 1, 1, 1, 1, 5, 1, 2, 1, 1, 1, 1, 7, 1, 1, 1, 1, 1, 1, 1, 34, 39, 1, 1, 1, 2])}
# passed
